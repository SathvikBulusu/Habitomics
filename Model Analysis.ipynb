# %% [markdown]
# ## We are utilisizing the dataset we have created and are now gonna call the dataset to start with exploratory data analysis to understand if there are any co-relations

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df= pd.read_csv("Preprocessed Dataset.csv")

df
# Out:
#     Year  CSUSHPINSA         CPI  IntrestRates     Gdp  median_price  \
# 0   2000    1257.326   78.970721      6.235833  145193        147300
# 1   2001    1358.228   81.202568      3.887500  148400        156600
# 2   2002    1467.454   82.490467      1.666667  151815        167600
# 3   2003    1604.898   84.363079      1.127500  157674        180200
# 4   2004    1805.577   86.621678      1.349167  166631        195200
# 5   2005    2061.354   89.560532      3.213333  176203        219000
# 6   2006    2201.771   92.449705      4.964167  184932        221900
# 7   2007    2159.310   95.086992      5.019167  191899        217900
# 8   2008    1968.722   98.737477      1.927500  193996        196600
# 9   2009    1782.630   98.386420      0.160000  188490        172100
# 10  2010    1735.967  100.000000      0.175000  194277        173100
# 11  2011    1670.874  103.156842      0.101667  199804        166200
# 12  2012    1691.831  105.291505      0.140000  206577        177200
# ...

# %% [markdown]
# # exploring the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Year                                      25 non-null     int64
#  1   CSUSHPINSA                                25 non-null     float64
#  2   CPI                                       25 non-null     float64
#  3   IntrestRates                              25 non-null     float64
#  4   Gdp                                       25 non-null     int64
#  5   median_price                              25 non-null     int64
#  6   Household-income                          25 non-null     int64
#  7   usp                                       25 non-null     float64
#  8   mort-rate                                 25 non-null     float64
#  9   Annual_unemp                              25 non-null     float64
# ...

# %%
df.describe()
# Out:
#               Year   CSUSHPINSA         CPI  IntrestRates            Gdp  \
# count    25.000000    25.000000   25.000000     25.000000      25.000000
# mean   2012.000000  2094.717200  105.277371      1.927067  208404.000000
# std       7.359801   636.622309   17.447957      2.008649   54774.153824
# min    2000.000000  1257.326000   78.970721      0.080000   84057.000000
# 25%    2006.000000  1691.831000   92.449705      0.160000  176203.000000
# 50%    2012.000000  1976.123000  105.291505      1.349167  199804.000000
# 75%    2018.000000  2296.573000  115.157303      3.213333  240001.000000
# max    2024.000000  3668.199000  139.735794      6.235833  326488.000000
#
#        median_price  Household-income          usp  mort-rate  Annual_unemp  \
# count      25.00000         25.000000    25.000000  25.000000     25.000000
# mean   235236.00000      69092.000000  1024.663117   5.155194     61.776000
# std     76570.33194       4557.191204   103.000984   1.381454     22.052594
# ...

# %%
df.rename(columns={'Urban population (% of total population)':'urban_population','houses sold':'houses_sold','selling price':'selling_price'},inplace=True)

# %% [markdown]
# # finding the correlation between the data
#
# ### we are going to create a correlation matrix and visualize it to see what are the positive and negative correlations

# %%
df_matrix = df.corr()
df_matrix
# Out:
#                       Year  CSUSHPINSA       CPI  IntrestRates       Gdp  \
# Year              1.000000    0.663758  0.979792     -0.191827  0.642354
# CSUSHPINSA        0.663758    1.000000  0.670757     -0.059088  0.919652
# CPI               0.979792    0.670757  1.000000     -0.069678  0.601849
# IntrestRates     -0.191827   -0.059088 -0.069678      1.000000 -0.307978
# Gdp               0.642354    0.919652  0.601849     -0.307978  1.000000
# median_price      0.847718    0.739110  0.897654      0.186841  0.528216
# Household-income  0.751627    0.672817  0.725852      0.178378  0.540940
# usp               0.780155    0.676755  0.701538     -0.233116  0.699447
# mort-rate        -0.517073   -0.309975 -0.364644      0.834702 -0.531702
# Annual_unemp     -0.238212   -0.237452 -0.295211     -0.659200 -0.021637
# urban_population  0.999250    0.684408  0.982178     -0.175518  0.655661
# houses_sold      -0.366778    0.023054 -0.412475      0.129739 -0.122598
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_matrix, annot=True, cmap='coolwarm', fmt= " .2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## understanding the HeatMap
#
# we see that the correlation here showcases that the red ones are highly corerelated and the blue ones are not that correlated at all

# %%
#which year the intrest rates were pretty high 
df_val=df.Year
df_val1=df.IntrestRates
fig, ax = plt.subplots(figsize=(6, 2.5),layout='constrained')
ax.scatter(df_val,df_val1)
ax.set_xlabel("Intrest rates")
ax.set_ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %% [markdown]
# # Observation
# ### 1 .Years (2000,2023,2024) have seen the highest rise of intrest rates in 20 years of total economy in united states
# ### 2. The Intrest Rates remained stable from years 2009 till 2016 with no increase
# ### 3. As we can see the intrest rates rised from 2017 to 2019 untill early 2020 due to covid-19
# ### 4. from the time period of 2020 - 2025 we see the unstable intrest rates

# %%
sns.pairplot(df)

# %% [markdown]
# ## Given above is the visualization of the pairs with rows and columns to find patterns

# %%
df.columns
# Out:
# Index(['Year', 'CSUSHPINSA', 'CPI', 'IntrestRates', 'Gdp', 'median_price',
#        'Household-income', 'usp', 'mort-rate', 'Annual_unemp',
#        'urban_population', 'houses_sold', 'selling_price', 'Population'],
#       dtype='object')

# %%
key_factors= df.columns 

key_factors
# Out:
# Index(['Year', 'CSUSHPINSA', 'CPI', 'IntrestRates', 'Gdp', 'median_price',
#        'Household-income', 'usp', 'mort-rate', 'Annual_unemp',
#        'urban_population', 'houses_sold', 'selling_price', 'Population'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7.5))
df[key_factors].hist(bins=20, alpha = 0.5, layout=(4,5) , figsize=(16,10))
plt.suptitle(" Histograms and plots",y=1.05)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### 1.We can see that Urban population and Year have a uniform distribution where as every other factor is not uniform.
# #### 2.Population factor is left skewed where as the intrests rate are right skewed.
# #### 3.From the above histograms we are able to find out outliers in Population , Annual umemployement , Gdp , case shiller index , Intrest rates , house hold income where we can now identify where exactly the outliers are present.

# %% [markdown]
# # As The Data factors are multi modal lets take Violin density Plots to understand the key factors and their distributions with their densities
#
# given below is the article for Understanding why we need Violin plots https://mode.com/blog/violin-plot-examples

# %%
f, mx = plt.subplots(figsize=(15, 11),layout='constrained')

# Show each distribution with both violins and points
sns.violinplot(data=df, palette="Set1", inner="points", cut=2, linewidth=3)

sns.despine(left=True)

f.suptitle('violin plots', fontsize=18, fontweight='bold')
mx.set_xlabel("factors",size = 12,alpha=0.7)
mx.set_ylabel("values",size = 12,alpha=0.7)
# Out:
# Text(0, 0.5, 'values')

# %% [markdown]
# ## Extracting the features and target to compare and contrast

# %%
X=df
y=df.pop('CSUSHPINSA')

# %%
y
# Out:
# 0     1257.326
# 1     1358.228
# 2     1467.454
# 3     1604.898
# 4     1805.577
# 5     2061.354
# 6     2201.771
# 7     2159.310
# 8     1968.722
# 9     1782.630
# 10    1735.967
# 11    1670.874
# 12    1691.831
# 13    1854.231
# 14    1976.123
# 15    2065.994
# 16    2170.878
# 17    2296.573
# 18    2429.460
# 19    2513.212
# 20    2665.289
# 21    3120.335
# 22    3581.264
# 23    3668.199
# 24    1260.430
# Name: CSUSHPINSA, dtype: float64

# %%
for feature in X.columns:
    plt.figure()
    plt.scatter(x = X[feature],y = y)
    plt.xlabel(feature)
    plt.ylabel('Case Shiller index')
    plt.title(f'Case shiller vs {feature}')
    plt.show()

# %% [markdown]
# # lets calculate correlations coefficients

# %%
correlations = X.apply(lambda column:np.abs(column.corr(y)))

sorted_corr = correlations.sort_values() # sorting in ascending values

print('factors with low correlation to target :')
print(sorted_corr)
# Out:
# factors with low correlation to target :
# houses_sold         0.023054
# IntrestRates        0.059088
# Annual_unemp        0.237452
# mort-rate           0.309975
# Population          0.536963
# Year                0.663758
# CPI                 0.670757
# Household-income    0.672817
# usp                 0.676755
# urban_population    0.684408
# median_price        0.739110
# selling_price       0.753277
# Gdp                 0.919652
# dtype: float64

# %% [markdown]
# # Observations:
#
#
# #### 1. Strongest Correlation: GDP (0.919652) has strong linear relationship with the case shiller prices.
#
# #### 2. Moderate Correlation : Year (0.663758),CPI (0.670757),Household-income (0.672817),usp (0.676755),urban_population (0.684408),median_price (0.739110),selling_price (0.753277). These Key factors have moderate positive correlation.
#
# #### 3. Lowest Correlation : houses_sold (0.023054),IntrestRates (0.059088),Annual_unemp (0.237452),mort-rate (0.309975),Population (0.536963). These factors have the lower correlation with the case shiller price.

# %% [markdown]
# # ----------- Data Science Models -----------

# %%
# we will drop the lower correlation columns 

cols=['houses_sold','IntrestRates','Annual_unemp','mort-rate','Population']

df.drop(columns=cols,inplace=True)

X = df #nd new dataset

# %%
X
# Out:
#     Year         CPI     Gdp  median_price  Household-income          usp  \
# 0   2000   78.970721  145193        147300             67470  1024.663117
# 1   2001   81.202568  148400        156600             66360   893.668384
# 2   2002   82.490467  151815        167600             65820   908.794505
# 3   2003   84.363079  157674        180200             65860   918.025084
# 4   2004   86.621678  166631        195200             65760   937.770444
# 5   2005   89.560532  176203        219000             66780   927.051183
# 6   2006   92.449705  184932        221900             67520   941.381978
# 7   2007   95.086992  191899        217900             68610   943.084740
# 8   2008   98.737477  193996        196600             66280   939.112400
# 9   2009   98.386420  188490        172100             65850   991.358925
# 10  2010  100.000000  194277        173100             64300   981.959652
# 11  2011  103.156842  199804        166200             63350   956.410816
# ...

# %%
# importing the models 

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.svm import SVR
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor
from xgboost import XGBRegressor
import warnings 
warnings.filterwarnings('ignore')

# %%
# Split data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X.iloc[:,1:], y, test_size=0.2, random_state=42)

# Create a list of feature names
feature_names = X.columns[1:].tolist()  # Assuming X has column names

# Standardize features
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(X_train.to_numpy())

# Transform the test data using the already fitted scaler
X_test_scaled = scaler.transform(X_test)

# Verify shapes
print(f"X_train_scaled shape: {X_train_scaled.shape}")
print(f"X_test_scaled shape: {X_test_scaled.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# X_train_scaled shape: (20, 7)
# X_test_scaled shape: (5, 7)
# Y_train shape: (20,)
# Y_test shape: (5,)

# %% [markdown]
# # exploring various regression models

# %%
models = {
    'Linear Regression': LinearRegression(),
    'ElasticNet': ElasticNet(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor(),
    'SVR': SVR(),
    'XGBoost': XGBRegressor()
}


best_model = None
best_mse = float('inf')

# Visualize actual vs. predicted values for all models
fig, axs = plt.subplots(2, 3, figsize=(12, 10))
axs = axs.flatten()

# Training and evaluation
for i, (name, model) in enumerate(models.items()):
    model.fit(X_train_scaled, Y_train)  
    y_pred = model.predict(X_test_scaled)  

    mse = mean_squared_error(Y_test, y_pred)
    r2 = r2_score(Y_test, y_pred)

    # Calculate absolute change percentage
    y_pred_abs_change = np.abs(Y_test - y_pred)
    y_pred_abs_change_pct = (y_pred_abs_change / Y_test) * 100
    mse_pct = np.mean(y_pred_abs_change_pct)
    
    print(f"Model: {name}")
    print(f"Mean Squared Error: {mse}%")
    print(f"mean squared error percentage: {mse_pct}%")
    print(f"R-squared: {r2}")

    # Display coefficients and intercept for linear models
    if hasattr(model, 'coef_'):
        print("Coefficients:")
        for j, coef in enumerate(model.coef_):
            print(f"Feature {feature_names[j]}: {coef}")
        
        print(f"Intercept: {model.intercept_}")
    else:
        # For non-linear models, display feature importance
        if hasattr(model, 'feature_importances_'):
            print("Feature Importance Analysis:")
            for j, importance in enumerate(model.feature_importances_):
                print(f"Feature {feature_names[j]}: {importance}")

    print()

    # Update best model if current model has lower MSE
    if mse < best_mse:
        best_mse = mse
        best_model = model
    
    # Plot actual vs. predicted values
    axs[i].scatter(Y_test, y_pred, label=name)
    axs[i].set_xlabel("Actual Home Prices")
    axs[i].set_ylabel("Predicted Home Prices")
    axs[i].set_title(f"Actual vs. Predicted ({name})")
    axs[i].legend()

# Tight layout for better spacing
plt.tight_layout()
plt.show()

print(f"\nBest Model: {type(best_model).__name__} with MSE: {best_mse}")
# Out:
# Model: Linear Regression
# Mean Squared Error: 19732.990345087823%
# mean squared error percentage: 3.6060688890269774%
# R-squared: 0.9706757100088803
# Coefficients:
# Feature CPI: -14.626037161098038
# Feature Gdp: 2509.0363069988457
# Feature median_price: 1892.8369060964374
# Feature Household-income: -62.267819312905324
# Feature usp: -224.71623085064653
# Feature urban_population: -750.1242697464456
# Feature selling_price: -581.6582161293724
# Intercept: 785.1547699738139
#
# Model: ElasticNet
# Mean Squared Error: 403952.4060532914%
# mean squared error percentage: 19.976912099398785%
# R-squared: 0.3997048956816629
# Coefficients:
# Feature CPI: 66.1092806223464
# Feature Gdp: 163.63679309215473
# Feature median_price: 103.10001784314878
# Feature Household-income: 114.21136729204348
# Feature usp: 169.225041833991
# Feature urban_population: 88.51903392452516
# Feature selling_price: 99.73845851119586
# Intercept: 1738.8367543741185
#
# Model: Random Forest
# ...

# %% [markdown]
# # Best model happens to be XGBOOST from comparision out of all the regression models with R-Squared - 0.9844451

# %%
# Assuming you have a DataFrame with model names and their corresponding evaluation metrics
data = {
    'Model': ['Linear Regression', 'ElasticNet', 'Random Forest', 'Gradient Boosting', 'SVR', 'XGBoost'],
    'MSE': [19732.99, 403952.40,163313.74,173327.93,686062.94, 10467.21],
    'R-squared': [0.970, 0.399, 0.757, 0.742, -0.019, 0.984]
}

df = pd.DataFrame(data)

# Create a table plot using matplotlib
fig, ax = plt.subplots(figsize=(6, 3)) 

# Hide the axes
ax.axis('off')

# Create a table and add data
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc = 'center', loc='center', colColours=['#f3f3f3']*len(df.columns), colWidths=[0.25]*len(df.columns))

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)  # Adjust the table size if needed

# Highlight specific values (e.g., minimum and maximum MSE)
min_mse_index = np.argmin(df['MSE'])
max_mse_index = np.argmax(df['MSE'])

for i in range(len(df)):
    for j in range(len(df.columns)):
        if (i == min_mse_index or i == max_mse_index) and j == df.columns.get_loc('MSE'):
            color = '#ffcccb' if i == min_mse_index else '#b0e57c'  # Light red for min and light green for max MSE
            table[(i + 1, j)].set_facecolor(color)

# Highlight min and max R-squared
min_r2_index = np.argmin(df['R-squared'])
max_r2_index = np.argmax(df['R-squared'])

for i in range(len(df)):
    for j in range(len(df.columns)):
        if (i == min_r2_index or i == max_r2_index) and j == df.columns.get_loc('R-squared'):
            color = '#ffcccb' if i == min_r2_index else '#b0e57c'  # Light red for min and light green for max R-squared
            table[(i + 1, j)].set_facecolor(color)

plt.title('Model Evaluation Metrics')
plt.show()

# %% [markdown]
# **Observation:**
#
# **Linear Regression** is  a strong contender, as the model has low MSE and high R-squared value. Additionally,model provides insights into feature importance.
#
# **ElasticNet,Random Forest,Gradient Boosting** have higher MSE values, indicating potential limitations in predictive accuracy.
#
#
# **Worst model:**
#
# **SVR** has a considerably higher MSE and lower R-squared, suggesting lower performance compared to other models.
#
# **Best model:**
# In summary, based on the provided metrics, **XGBOOST** appears to be a **strong candidate** for the best model, with a low MSE and a high R-squared value.
#
#
# **Low MSE:** The low MSE indicates that the model's predictions are close to the actual values on average, suggesting good predictive accuracy.
#
#
# **High R-squared:** The high R-squared value suggests that a significant portion of the variance in home prices is explained by the model. This indicates strong explanatory power.
#
#
# **Feature Importance:** The feature importance analysis provides transparency into the factors driving the predictions. In my case, features like '**CPI**', '**GDP**' and '**median_price**'are identified as influential.
#
# This means that, according to the model, changes in these features have a notable impact on the predictions of U.S. home prices. For example, if 'CPI' increases, it suggests that changes in the cost of living might influence home prices.
#
# Understanding feature importance is crucial for making informed decisions, refining models, and gaining insights into the factors driving the predictions, which is especially valuable in fields like economics, finance, or real estate where interpretability is essential.
